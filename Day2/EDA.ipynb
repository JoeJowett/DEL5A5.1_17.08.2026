# %% [markdown]
# # This is a title
# ## This is a subtitle
# These are notes:
# - Note 1
# - Note 2

# %%
print ("hello world")
# Out:
# hello world

# %%
# Task

# %% [markdown]
# # Task:
# 1. Download csv files
# 2. Load into this notebook
# 3. Clean the csvs
# 4. Output clean files

# %% [markdown]
# Pandas Demo

# %%
import pandas as pd

# %%
data = pd.read_csv("Data/03_Library SystemCustomers.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 3          NaN               NaN
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted>

# %%
customers = data
customers.head
# Out:
# <bound method NDFrame.head of    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 3          NaN               NaN
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted>

# %%
del data

# %%
customers = customers.dropna()
customers.head
# Out:
# <bound method NDFrame.head of    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted>

# %%
customers.to_csv("Data/03_Library SystemCustomers_clean.csv, index=False")

# %%
books = pd.read_csv("Data/03_Library Systembook.csv")

# %%
books.head
# Out:
# <bound method NDFrame.head of       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaN
# 110  NaN                                       NaN           NaN
# 111  NaN                                       NaN           NaN
# 112  NaN                                       NaN           NaN
# 113  NaN                                       NaN           NaN
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# ...

# %%
books = books.dropna()
books.head
# Out:
# <bound method NDFrame.head of       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...

# %%
books.head()
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye   "20/02/2023"    25/02/2023
# 1  2.0          Lord of the rings the two towers  "24/03/2023"    21/03/2023
# 2  3.0  Lord of the rings the return of the kind  "29/03/2023"    25/03/2023
# 3  4.0                                The hobbit  "02/04/2023"    25/03/2023
# 4  5.0                                     Dune   "02/04/2023"    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0

# %%
books['Book checkout'] = pd.to_datetime(
    books['Book checkout'].str.strip('"'),
    dayfirst=True,
    errors='coerce')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7364\4154754968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['Book checkout'] = pd.to_datetime(

# %%
books.head()
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye     2023-02-20    25/02/2023
# 1  2.0          Lord of the rings the two towers    2023-03-24    21/03/2023
# 2  3.0  Lord of the rings the return of the kind    2023-03-29    25/03/2023
# 3  4.0                                The hobbit    2023-04-02    25/03/2023
# 4  5.0                                     Dune     2023-04-02    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0

# %%
books['Book Returned'] = pd.to_datetime(
    books['Book Returned'].str.strip('"'),
    dayfirst=True,
    errors='coerce')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7364\2856880438.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['Book Returned'] = pd.to_datetime(

# %%
books.head()
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye     2023-02-20    2023-02-25
# 1  2.0          Lord of the rings the two towers    2023-03-24    2023-03-21
# 2  3.0  Lord of the rings the return of the kind    2023-03-29    2023-03-25
# 3  4.0                                The hobbit    2023-04-02    2023-03-25
# 4  5.0                                     Dune     2023-04-02    2023-03-25
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0

# %%
books['Days allowed to borrow'] = (
    books['Days allowed to borrow']
    .astype(str)
    .str.extract(r'(\d+(?:\.\d+)?)')[0]
)
books['Days allowed to borrow'] = pd.to_numeric(
    books['Days allowed to borrow'],
   errors='coerce' 
) * 7
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7364\2433613532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['Days allowed to borrow'] = (
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7364\2433613532.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['Days allowed to borrow'] = pd.to_numeric(

# %%
books.head()
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye     2023-02-20    2023-02-25
# 1  2.0          Lord of the rings the two towers    2023-03-24    2023-03-21
# 2  3.0  Lord of the rings the return of the kind    2023-03-29    2023-03-25
# 3  4.0                                The hobbit    2023-04-02    2023-03-25
# 4  5.0                                     Dune     2023-04-02    2023-03-25
#
#    Days allowed to borrow  Customer ID
# 0                      14          1.0
# 1                      14          2.0
# 2                      14          3.0
# 3                      14          4.0
# 4                      14          5.0

# %%
books.to_csv("Data/03_Library Systembook_clean.csv, index=False")

# %%
# calculate the difference between checkout and return

def calculate_days_difference(row):
    return (row['Book Returned'] - row['Book checkout']).days
books['Days Borrowed'] = books.apply(calculate_days_difference, axis=1)
books.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7364\727830314.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['Days Borrowed'] = books.apply(calculate_days_difference, axis=1)
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye     2023-02-20    2023-02-25
# 1  2.0          Lord of the rings the two towers    2023-03-24    2023-03-21
# 2  3.0  Lord of the rings the return of the kind    2023-03-29    2023-03-25
# 3  4.0                                The hobbit    2023-04-02    2023-03-25
# 4  5.0                                     Dune     2023-04-02    2023-03-25
#
#    Days allowed to borrow  Customer ID  Days Borrowed
# ...

# %%
books['Overdue'] = books['Days Borrowed'].apply(
    lambda x: 'Overdue' if x > 14 else 'On time'
)
books.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7364\2646886661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['Overdue'] = books['Days Borrowed'].apply(
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye     2023-02-20    2023-02-25
# 1  2.0          Lord of the rings the two towers    2023-03-24    2023-03-21
# 2  3.0  Lord of the rings the return of the kind    2023-03-29    2023-03-25
# 3  4.0                                The hobbit    2023-04-02    2023-03-25
# 4  5.0                                     Dune     2023-04-02    2023-03-25
#
#    Days allowed to borrow  Customer ID  Days Borrowed  Overdue
# ...

# %%
books.to_csv("Data/03_Library Systembook_cleaner.csv, index=False")
